# %%
import numpy as np
import pandas as pd

df = pd.read_csv("resultados_tsp_fase_3.csv")

# %%
df_sort = df.sort_values(by="Mejor_Fitness", ascending=True)
df_sort.head()
# Out:
#                                          Configuracion         Cruza  \
# 307  cruce_bordes | mutacion_insercion | mut:0.05 |...  cruce_bordes
# 508  cruce_bordes | mutacion_insercion | mut:0.2 | ...  cruce_bordes
# 509  cruce_bordes | mutacion_insercion | mut:0.2 | ...  cruce_bordes
# 520  cruce_bordes | mutacion_insercion | mut:0.2 | ...  cruce_bordes
# 539  cruce_bordes | mutacion_insercion | mut:0.2 | ...  cruce_bordes
#
#                Mutacion  Tasa_mutacion  Tam_poblacion  Ejecución No.  \
# 307  mutacion_insercion           0.05            100              7
# 508  mutacion_insercion           0.20            100             28
# 509  mutacion_insercion           0.20            100             29
# 520  mutacion_insercion           0.20            200             10
# 539  mutacion_insercion           0.20            200             29
#
#      Elitismo  Mejor_Fitness  Diversidad_Final
# 307     False   66633.436113          0.016579
# ...

# %%
df_final = df_sort.head()
df_final.to_latex('Resultados_fase_3.tex', columns=["Cruza", "Mutacion", "Tasa_mutacion", "Elitismo", "Mejor_Fitness", "Diversidad_Final"])
