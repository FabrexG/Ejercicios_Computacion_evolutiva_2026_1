# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("resultados_tsp_fase_2.csv")

# %%
df_sort = df.sort_values(by="Mejor_Fitness", ascending=True)

# %%
df_result = df_sort.head()

# %%
df_result
# Out:
#                                         Configuracion         Cruza  \
# 1   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 9   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 25  cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 39  cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 61  cruce_bordes | mutacion_insercion | mut:0.05 |...  cruce_bordes
#
#                 Mutacion  Tasa_mutacion  Tam_poblacion  Ejecución No.  \
# 1   mutacion_intercambio           0.05            100              1
# 9   mutacion_intercambio           0.05            100              9
# 25  mutacion_intercambio           0.05            100             25
# 39  mutacion_intercambio           0.05            100              9
# 61    mutacion_insercion           0.05            100              1
#
#     Elitismo  Mejor_Fitness  Diversidad_Final
# 1       True   66633.436113          0.005789
# ...

# %%
df_result.to_latex("Resultado_fase_2.tex", columns=["Cruza", "Mutacion", "Tasa_mutacion", "Elitismo", "Mejor_Fitness", "Diversidad_Final"])
