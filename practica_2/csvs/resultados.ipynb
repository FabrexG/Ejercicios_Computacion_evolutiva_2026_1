# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("resultados_tsp_fase_3.csv")

# %%
df_sort = df.sort_values(by="Mejor_Fitness", ascending=True)

# %%
df_sort.head(20)
# Out:
#                                          Configuracion         Cruza  \
# 530  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 497  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 44   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 39   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 245  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 250  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 243  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 241  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 63   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 268  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 267  cruce_bordes | mutacion_intercambio | mut:0.2 ...  cruce_bordes
# 60   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# 54   cruce_bordes | mutacion_intercambio | mut:0.05...  cruce_bordes
# ...

# %%
df_result = df_sort.head()

# %%
df_result
# Out:
#                                           Configuracion         Cruza  \
# 3758  cruce_bordes | mutacion_desordenada | mut:0.2 ...  cruce_bordes
# 5856  cruce_orden | mutacion_desordenada | mut:0.2 |...   cruce_orden
# 2554  cruce_bordes | mutacion_intercambio | mut:0.1 ...  cruce_bordes
# 1717  cruce_pmx | mutacion_inversion | mut:0.1 | pob...     cruce_pmx
# 944   cruce_pmx | mutacion_insercion | mut:0.1 | pob...     cruce_pmx
#
#                   Mutacion  Tasa_mutacion  Tam_poblacion  Ejecución No.  \
# 3758  mutacion_desordenada            0.2            200              8
# 5856  mutacion_desordenada            0.2             50              6
# 2554  mutacion_intercambio            0.1            100              4
# 1717    mutacion_inversion            0.1             50              7
# 944     mutacion_insercion            0.1            100             14
#
#       Elitismo  Mejor_Fitness  Diversidad_Final
# 3758     False   66633.436113          0.113947
# ...

# %%
df_result.to_latex("Resultado_todos.tex", columns=["Cruza", "Mutacion", "Tasa_mutacion", "Tam_poblacion", "Elitismo", "Mejor_Fitness", "Diversidad_Final"])
