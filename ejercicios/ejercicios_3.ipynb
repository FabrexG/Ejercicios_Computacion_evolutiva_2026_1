# %%
import numpy as np
x = ([3.7, 5.1, 3.0], [(2, 5), (-10, 7), (-7, 17)])

# %%
x
# Out:
# ([3.7, 5.1, 3.0], [(2, 5), (-10, 7), (-7, 17)])

# %%
def mutacion_uniforme(individuo, tasa_mutacion):
    for i in range(len(individuo[0])):
        p = np.random.random()
        print(individuo[0][i])
        print(individuo[1][i])
        print(individuo[0][i])
        if p < tasa_mutacion:
            pass

# %%
mutacion_uniforme(x, 0.5)
# Out:
# 3.7
# (2, 5)
# 3.7
# 5.1
# (-10, 7)
# 5.1
# 3.0
# (-7, 17)
# 3.0
