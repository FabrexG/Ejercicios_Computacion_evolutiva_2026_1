# %%
import numpy as np
import pandas as pd

df = pd.read_csv("resultados_experimentos_neat_fase_3.csv")

# %%
df
# Out:
#     Dimensiones Representacion  Fitness_Evolutivo   F1_Test  Nodos_Finales  \
# 0           0.3             WE           0.627215  0.407514              3
# 1           0.3             WE           0.610431  0.423132              3
# 2           0.3             WE           0.550001  0.374456              4
# 3           0.3             WE           0.632685  0.410691              3
# 4           0.3             WE           0.573999  0.425482              3
# 5           0.3             WE           0.527261  0.365622              5
# 6           0.3             WE           0.607199  0.453365              4
# 7           0.3             WE           0.602673  0.383221              3
# 8           0.3             WE           0.588574  0.459666              3
# 9           0.3             WE           0.621264  0.424550              4
# 10          0.3             WE           0.580063  0.419472              3
# ...

# %%
df_sort = df.sort_values(by="F1_Test", ascending=False)
df_sort.head()
# Out:
#     Dimensiones Representacion  Fitness_Evolutivo   F1_Test  Nodos_Finales  \
# 18          0.3             WE           0.575957  0.490991              4
# 20          0.3             WE           0.541790  0.471703              3
# 13          0.3             WE           0.565117  0.465655              4
# 8           0.3             WE           0.588574  0.459666              3
# 6           0.3             WE           0.607199  0.453365              4
#
#     Conexiones_Finales  pop_size  node_add_prob  conn_add_prob  \
# 18                 162       400            0.1            0.1
# 20                 161       400            0.1            0.1
# 13                 163       400            0.1            0.1
# 8                  160       400            0.1            0.1
# 6                  162       400            0.1            0.1
#
#     conn_delete_prob  compatibility_threshold  weight_mutate_rate  \
# ...

# %%
df_final = df_sort.head()
df_final.to_latex('Resultados_fase_2.tex', columns=["Representacion", "Dimensiones", "Fitness_Evolutivo", "F1_Test", "Nodos_Finales", "Conexiones_Finales", "pop_size"])

# %%
df_final = df_sort.head()
df_final.to_latex('Resultados_fase_3.tex', columns=["compatibility_threshold", "weight_mutate_rate", "survival_threshold", "Fitness_Evolutivo", "F1_Test"])
